# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#read in Boston 2018 weather csv
weather_csv_path = "Resources/2018weather.csv"

weather_df = pd.read_csv(weather_csv_path)
weather_df.head()
# Out:
#        STATION           NAME    DATE   AWND  PRCP  SNOW  TAVG
# 0  USW00014739  BOSTON, MA US  1/1/18  16.33  0.00   0.0     6
# 1  USW00014739  BOSTON, MA US  1/2/18  12.75  0.00   0.0    10
# 2  USW00014739  BOSTON, MA US  1/3/18   9.40  0.00   0.0    21
# 3  USW00014739  BOSTON, MA US  1/4/18  22.59  1.35  13.4    26
# 4  USW00014739  BOSTON, MA US  1/5/18  24.83  0.00   0.0    18

# %%
#count and check for any missing values
weather_df.count()
# Out:
# STATION    365
# NAME       365
# DATE       365
# AWND       365
# PRCP       365
# SNOW       365
# TAVG       365
# dtype: int64

# %%
#view columns
weather_df.columns
# Out:
# Index(['STATION', 'NAME', 'DATE', 'AWND', 'PRCP', 'SNOW', 'TAVG'], dtype='object')

# %%
#create new df with only the following columns
reduced_weather_df = weather_df.loc[:, ["DATE", "AWND", "PRCP", "SNOW", "TAVG"]]
reduced_weather_df.head()
# Out:
#      DATE   AWND  PRCP  SNOW  TAVG
# 0  1/1/18  16.33  0.00   0.0     6
# 1  1/2/18  12.75  0.00   0.0    10
# 2  1/3/18   9.40  0.00   0.0    21
# 3  1/4/18  22.59  1.35  13.4    26
# 4  1/5/18  24.83  0.00   0.0    18

# %%
#rename columns
reduced_weather_df = reduced_weather_df.rename(columns={"DATE": "Date",
                                                        "AWND": "Average Wind Speed",
                                                       "PRCP": "Precipitation",
                                                        "SNOW": "Snow",
                                                       "TAVG": "Average Temperature"})
reduced_weather_df.columns
# Out:
# Index(['Date', 'Average Wind Speed', 'Precipitation', 'Snow',
#        'Average Temperature'],
#       dtype='object')

# %%
reduced_weather_df.head()
# Out:
#      Date  Average Wind Speed  Precipitation  Snow  Average Temperature
# 0  1/1/18               16.33           0.00   0.0                    6
# 1  1/2/18               12.75           0.00   0.0                   10
# 2  1/3/18                9.40           0.00   0.0                   21
# 3  1/4/18               22.59           1.35  13.4                   26
# 4  1/5/18               24.83           0.00   0.0                   18

# %%
reduced_weather_df.dtypes
# Out:
# Date                    object
# Average Wind Speed     float64
# Precipitation          float64
# Snow                   float64
# Average Temperature      int64
# dtype: object

# %%
# #set x axis and tick location
# x_axis = np.arange(len(reduced_weather_df))
# tick_locations = [value for value in x_axis]

# %%
# plt.bar(reduced_weather_df[:30]["Date"], reduced_weather_df[:30]["Snow"])
# plt.tight_layout()
# plt.xticks(rotation='vertical')

# %%
#convert to monthly
# reduced_weather_df.set_index("Date", inplace = True)
# reduced_weather_df.index = pd.to_datetime(reduced_weather_df.index)
# reduced_weather_df.resample('1M').mean()
# reduced_weather_df = reduced_weather_df.reset_index()

# %%
#reduced_weather_df.columns

# %%
#creat new columns for year, month, day
reduced_weather_df.reset_index()
reduced_weather_df["Date_Time"] = pd.to_datetime(reduced_weather_df["Date"])
reduced_weather_df["Year"] = reduced_weather_df["Date_Time"].dt.year
reduced_weather_df["Month"] = reduced_weather_df["Date_Time"].dt.month
reduced_weather_df["Day"] = reduced_weather_df["Date_Time"].dt.day
reduced_weather_df
# Out:
#          Date  Average Wind Speed  Precipitation  Snow  Average Temperature  \
# 0      1/1/18               16.33           0.00   0.0                    6
# 1      1/2/18               12.75           0.00   0.0                   10
# 2      1/3/18                9.40           0.00   0.0                   21
# 3      1/4/18               22.59           1.35  13.4                   26
# 4      1/5/18               24.83           0.00   0.0                   18
# ..        ...                 ...            ...   ...                  ...
# 360  12/27/18                9.17           0.00   0.0                   34
# 361  12/28/18               11.41           0.33   0.0                   41
# 362  12/29/18               13.20           0.00   0.0                   49
# 363  12/30/18                6.26           0.00   0.0                   32
# 364  12/31/18               10.51           0.41   0.0                   36
#
#      Date_Time  Year  Month  Day
# 0   2018-01-01  2018      1    1
# 1   2018-01-02  2018      1    2
# 2   2018-01-03  2018      1    3
# 3   2018-01-04  2018      1    4
# 4   2018-01-05  2018      1    5
# ..         ...   ...    ...  ...
# 360 2018-12-27  2018     12   27
# 361 2018-12-28  2018     12   28
# 362 2018-12-29  2018     12   29
# 363 2018-12-30  2018     12   30
# 364 2018-12-31  2018     12   31
#
# [365 rows x 9 columns]

# %%
#group by month 
group_month_df = reduced_weather_df.groupby(["Month"]).mean()
group_month_df
group_month_df = group_month_df.reset_index()
group_month_df
# Out:
#     Month  Average Wind Speed  Precipitation      Snow  Average Temperature  \
# 0       1           13.327742       0.158710  0.574194            28.580645
# 1       2           11.081071       0.134643  0.296429            38.107143
# 2       3           15.089032       0.163548  0.751613            36.741935
# 3       4           11.938333       0.154000  0.043333            44.700000
# 4       5           10.001613       0.061290  0.000000            60.870968
# 5       6           10.253333       0.098667  0.000000            67.366667
# 6       7            9.870968       0.146774  0.000000            75.870968
# 7       8            9.466129       0.150000  0.000000            76.935484
# 8       9            9.656333       0.170667  0.000000            68.366667
# 9      10           11.206452       0.121935  0.000000            54.258065
# 10     11           12.541333       0.308667  0.003333            43.100000
# 11     12           10.830323       0.087742  0.003226            37.451613
#
#       Year   Day
# 0   2018.0  16.0
# 1   2018.0  14.5
# 2   2018.0  16.0
# 3   2018.0  15.5
# 4   2018.0  16.0
# 5   2018.0  15.5
# 6   2018.0  16.0
# 7   2018.0  16.0
# 8   2018.0  15.5
# 9   2018.0  16.0
# 10  2018.0  15.5
# 11  2018.0  16.0

# %%
#bar graph of monthly snow
# group_month_df.plot.bar(y = 'Snow')

# %%
#create a bar chart for monthly snow fall
plt.bar(group_month_df["Month"], group_month_df["Snow"])
plt.title("Snow in 2018")
plt.ylabel("Amount of Snow")
plt.xlabel("Month")
plt.xticks(np.arange(1, 12+1, 1.0))
plt.show()

# %%
#create bar chart for monthly precipitation
plt.bar(group_month_df["Month"], group_month_df["Precipitation"])
plt.title("Monthly Precipitation")
plt.ylabel("Precipitation")
plt.xlabel("Month")
plt.xticks(np.arange(1, 12+1, 1.0))
plt.show()

# %%
#import customer satisfaction CSVs
csat_files = ["Resources/csat_result_2018_01_Jan.csv",
             "Resources/csat_result_2018_02_Feb.csv",
             "Resources/csat_result_2018_03_Mar.csv",
             "Resources/csat_result_2018_04_Apr.csv",
             "Resources/csat_result_2018_05_May.csv",
             "Resources/csat_result_2018_06_Jun.csv",
             "Resources/csat_result_2018_07_Jul.csv",
             "Resources/csat_result_2018_08_Aug.csv",
             "Resources/csat_result_2018_09_Sep.csv",
             "Resources/csat_result_2018_10_Oct.csv",
             "Resources/csat_result_2018_11_Nov.csv",
             "Resources/csat_result_2018_12_Dec.csv"]

final_csat_df = pd.DataFrame({})

#loop to import and merge CSVs into df
for file in csat_files:
    tmp = pd.read_csv(file)
    final_csat_df = final_csat_df.append(tmp)
    
final_csat_df
# Out:
#     survey_id survey_date                  survey_name  \
# 0         500  2018-01-01  MBTA Customer Opinion Panel
# 1         501  2018-01-01  MBTA Customer Opinion Panel
# 2         502  2018-01-01  MBTA Customer Opinion Panel
# 3         503  2018-01-01  MBTA Customer Opinion Panel
# 4         504  2018-01-01  MBTA Customer Opinion Panel
# ..        ...         ...                          ...
# 3        1241  2018-12-01  MBTA Customer Opinion Panel
# 4        1279  2018-12-01  MBTA Customer Opinion Panel
# 5        1280  2018-12-01  MBTA Customer Opinion Panel
# 6        1281  2018-12-01  MBTA Customer Opinion Panel
# 7        1282  2018-12-01  MBTA Customer Opinion Panel
#
#                                  question_description  response_total  \
# 0                How would you rate the mbta overall?             895
# 1           How would you rate your most recent trip?             886
# 2   How likely are you to continue using the mbta ...             884
# 3   How likely are you to recommend the mbta to a ...             883
# 4   The mbta provides reliable public transportati...             883
# ..                                                ...             ...
# 3   How satisfied are you with the MBTA's communic...            1300
# 4                How would you rate the mbta overall?            1300
# 5           How would you rate your most recent trip?            1293
# 6   The mbta provides reliable public transportati...            1290
# 7   How satisfied are you with the MBTA's communic...            1300
#
#            response_1_text  response_1_percent    response_2_text  \
# 0   Extremely Dissatisfied              0.0922  Very Dissatisfied
# 1   Extremely Dissatisfied              0.1247  Very Dissatisfied
# 2       Extremely Unlikely              0.0111      Very Unlikely
# 3       Extremely Unlikely              0.0944      Very Unlikely
# 4        Strongly Disagree              0.2048           Disagree
# ..                     ...                 ...                ...
# 3   Extremely Dissatisfied              0.0583  Very Dissatisfied
# 4   Extremely Dissatisfied              0.0591  Very Dissatisfied
# 5   Extremely Dissatisfied              0.0496  Very Dissatisfied
# 6        Strongly Disagree              0.1054           Disagree
# 7   Extremely Dissatisfied              0.0583  Very Dissatisfied
#
#     response_2_percent        response_3_text  response_3_percent  \
# 0               0.0922  Somewhat Dissatisfied              0.1379
# 1               0.1247  Somewhat Dissatisfied              0.1027
# 2               0.0111      Somewhat Unlikely              0.0171
# 3               0.0944      Somewhat Unlikely              0.0764
# 4               0.2048      Slightly Disagree              0.1567
# ..                 ...                    ...                 ...
# 3               0.0583  Somewhat Dissatisfied              0.1138
# 4               0.0591  Somewhat Dissatisfied              0.1164
# 5               0.0496  Somewhat Dissatisfied              0.0983
# 6               0.1054      Slightly Disagree              0.1665
# 7               0.0583  Somewhat Dissatisfied              0.1138
#
#                 response_4_text  response_4_percent     response_5_text  \
# 0                       Neutral              0.0820  Somewhat Satisfied
# 1                       Neutral              0.1025  Somewhat Satisfied
# 2   Neither Likely nor Unlikely              0.0373     Somewhat Likely
# 3   Neither Likely nor Unlikely              0.1516     Somewhat Likely
# 4    Neither Agree nor Disagree              0.1157      Slightly Agree
# ..                          ...                 ...                 ...
# 3                       Neutral              0.1224  Somewhat Satisfied
# 4                       Neutral              0.0863  Somewhat Satisfied
# 5                       Neutral              0.1003  Somewhat Satisfied
# 6    Neither Agree nor Disagree              0.1062      Slightly Agree
# 7                       Neutral              0.1224  Somewhat Satisfied
#
#     response_5_percent response_6_text  response_6_percent  \
# 0               0.2062  Very Satisfied              0.2920
# 1               0.1444  Very Satisfied              0.3455
# 2               0.0666     Very Likely              0.2036
# 3               0.1811     Very Likely              0.1946
# 4               0.2078           Agree              0.1688
# ..                 ...             ...                 ...
# 3               0.2815  Very Satisfied              0.2642
# 4               0.2691  Very Satisfied              0.3302
# 5               0.1553  Very Satisfied              0.4219
# 6               0.2877           Agree              0.1896
# 7               0.2815  Very Satisfied              0.2642
#
#         response_7_text  response_7_percent
# 0   Extremely Satisfied              0.0452
# 1   Extremely Satisfied              0.0878
# 2      Extremely Likely              0.6540
# 3      Extremely Likely              0.2432
# 4        Strongly Agree              0.0245
# ..                  ...                 ...
# 3   Extremely Satisfied              0.0466
# 4   Extremely Satisfied              0.0362
# 5   Extremely Satisfied              0.1105
# 6        Strongly Agree              0.0261
# 7   Extremely Satisfied              0.0466
#
# [264 rows x 19 columns]

# %%
del final_csat_df["survey_id"]
final_csat_df = final_csat_df.drop_duplicates()
final_csat_df
# Out:
#    survey_date                  survey_name  \
# 0   2018-01-01  MBTA Customer Opinion Panel
# 1   2018-01-01  MBTA Customer Opinion Panel
# 2   2018-01-01  MBTA Customer Opinion Panel
# 3   2018-01-01  MBTA Customer Opinion Panel
# 4   2018-01-01  MBTA Customer Opinion Panel
# ..         ...                          ...
# 3   2018-11-01  MBTA Customer Opinion Panel
# 0   2018-12-01  MBTA Customer Opinion Panel
# 1   2018-12-01  MBTA Customer Opinion Panel
# 2   2018-12-01  MBTA Customer Opinion Panel
# 3   2018-12-01  MBTA Customer Opinion Panel
#
#                                  question_description  response_total  \
# 0                How would you rate the mbta overall?             895
# 1           How would you rate your most recent trip?             886
# 2   How likely are you to continue using the mbta ...             884
# 3   How likely are you to recommend the mbta to a ...             883
# 4   The mbta provides reliable public transportati...             883
# ..                                                ...             ...
# 3   How satisfied are you with the MBTA's communic...            1391
# 0                How would you rate the mbta overall?            1300
# 1           How would you rate your most recent trip?            1293
# 2   The mbta provides reliable public transportati...            1290
# 3   How satisfied are you with the MBTA's communic...            1300
#
#            response_1_text  response_1_percent    response_2_text  \
# 0   Extremely Dissatisfied              0.0922  Very Dissatisfied
# 1   Extremely Dissatisfied              0.1247  Very Dissatisfied
# 2       Extremely Unlikely              0.0111      Very Unlikely
# 3       Extremely Unlikely              0.0944      Very Unlikely
# 4        Strongly Disagree              0.2048           Disagree
# ..                     ...                 ...                ...
# 3   Extremely Dissatisfied              0.0551  Very Dissatisfied
# 0   Extremely Dissatisfied              0.0591  Very Dissatisfied
# 1   Extremely Dissatisfied              0.0496  Very Dissatisfied
# 2        Strongly Disagree              0.1054           Disagree
# 3   Extremely Dissatisfied              0.0583  Very Dissatisfied
#
#     response_2_percent        response_3_text  response_3_percent  \
# 0               0.0922  Somewhat Dissatisfied              0.1379
# 1               0.1247  Somewhat Dissatisfied              0.1027
# 2               0.0111      Somewhat Unlikely              0.0171
# 3               0.0944      Somewhat Unlikely              0.0764
# 4               0.2048      Slightly Disagree              0.1567
# ..                 ...                    ...                 ...
# 3               0.0551  Somewhat Dissatisfied              0.1160
# 0               0.0591  Somewhat Dissatisfied              0.1164
# 1               0.0496  Somewhat Dissatisfied              0.0983
# 2               0.1054      Slightly Disagree              0.1665
# 3               0.0583  Somewhat Dissatisfied              0.1138
#
#                 response_4_text  response_4_percent     response_5_text  \
# 0                       Neutral              0.0820  Somewhat Satisfied
# 1                       Neutral              0.1025  Somewhat Satisfied
# 2   Neither Likely nor Unlikely              0.0373     Somewhat Likely
# 3   Neither Likely nor Unlikely              0.1516     Somewhat Likely
# 4    Neither Agree nor Disagree              0.1157      Slightly Agree
# ..                          ...                 ...                 ...
# 3                       Neutral              0.1348  Somewhat Satisfied
# 0                       Neutral              0.0863  Somewhat Satisfied
# 1                       Neutral              0.1003  Somewhat Satisfied
# 2    Neither Agree nor Disagree              0.1062      Slightly Agree
# 3                       Neutral              0.1224  Somewhat Satisfied
#
#     response_5_percent response_6_text  response_6_percent  \
# 0               0.2062  Very Satisfied              0.2920
# 1               0.1444  Very Satisfied              0.3455
# 2               0.0666     Very Likely              0.2036
# 3               0.1811     Very Likely              0.1946
# 4               0.2078           Agree              0.1688
# ..                 ...             ...                 ...
# 3               0.2896  Very Satisfied              0.2704
# 0               0.2691  Very Satisfied              0.3302
# 1               0.1553  Very Satisfied              0.4219
# 2               0.2877           Agree              0.1896
# 3               0.2815  Very Satisfied              0.2642
#
#         response_7_text  response_7_percent
# 0   Extremely Satisfied              0.0452
# 1   Extremely Satisfied              0.0878
# 2      Extremely Likely              0.6540
# 3      Extremely Likely              0.2432
# 4        Strongly Agree              0.0245
# ..                  ...                 ...
# 3   Extremely Satisfied              0.0489
# 0   Extremely Satisfied              0.0362
# 1   Extremely Satisfied              0.1105
# 2        Strongly Agree              0.0261
# 3   Extremely Satisfied              0.0466
#
# [132 rows x 18 columns]

# %%
#count to check for any missing values
final_csat_df.count()
# Out:
# survey_date             132
# survey_name             132
# question_description    126
# response_total          132
# response_1_text         132
# response_1_percent      132
# response_2_text         132
# response_2_percent      132
# response_3_text         132
# response_3_percent      132
# response_4_text         132
# response_4_percent      132
# response_5_text         132
# response_5_percent      132
# response_6_text         132
# response_6_percent      132
# response_7_text         132
# response_7_percent      132
# dtype: int64

# %%
#drop null values
final_csat_df = final_csat_df.dropna(how='any')
final_csat_df.count()
# Out:
# survey_date             126
# survey_name             126
# question_description    126
# response_total          126
# response_1_text         126
# response_1_percent      126
# response_2_text         126
# response_2_percent      126
# response_3_text         126
# response_3_percent      126
# response_4_text         126
# response_4_percent      126
# response_5_text         126
# response_5_percent      126
# response_6_text         126
# response_6_percent      126
# response_7_text         126
# response_7_percent      126
# dtype: int64

# %%
final_csat_df.columns
# Out:
# Index(['survey_date', 'survey_name', 'question_description', 'response_total',
#        'response_1_text', 'response_1_percent', 'response_2_text',
#        'response_2_percent', 'response_3_text', 'response_3_percent',
#        'response_4_text', 'response_4_percent', 'response_5_text',
#        'response_5_percent', 'response_6_text', 'response_6_percent',
#        'response_7_text', 'response_7_percent'],
#       dtype='object')

# %%
#rename columns so it looks cleaner
final_csat_df = final_csat_df.rename(columns={"survey_date": "Date",
                                             "question_description": "Question",
                                             "response_total": "Total Response",
                                             "response_1_text": "Response 1",
                                             "response_1_percent": "% Response 1",
                                             "response_2_text": "Response 2",
                                             "response_2_percent": "% Response 2",
                                             "response_3_text": "Response 3",
                                             "response_3_percent":"% Response 3",
                                             "response_4_text": "Response 4",
                                            "response_4_percent":"% Response 4",
                                             "response_5_text": "Response 5",
                                              "response_5_percent":"% Response 5",
                                             "response_6_text": "Response 6",
                                             "response_6_percent":"% Response 6",
                                             "response_7_text": "Response 7",
                                             "response_7_percent":"% Response 7"})

final_csat_df.head()
# Out:
#          Date                  survey_name  \
# 0  2018-01-01  MBTA Customer Opinion Panel
# 1  2018-01-01  MBTA Customer Opinion Panel
# 2  2018-01-01  MBTA Customer Opinion Panel
# 3  2018-01-01  MBTA Customer Opinion Panel
# 4  2018-01-01  MBTA Customer Opinion Panel
#
#                                             Question  Total Response  \
# 0               How would you rate the mbta overall?             895
# 1          How would you rate your most recent trip?             886
# 2  How likely are you to continue using the mbta ...             884
# 3  How likely are you to recommend the mbta to a ...             883
# 4  The mbta provides reliable public transportati...             883
#
#                Response 1  % Response 1         Response 2  % Response 2  \
# 0  Extremely Dissatisfied        0.0922  Very Dissatisfied        0.0922
# 1  Extremely Dissatisfied        0.1247  Very Dissatisfied        0.1247
# 2      Extremely Unlikely        0.0111      Very Unlikely        0.0111
# 3      Extremely Unlikely        0.0944      Very Unlikely        0.0944
# 4       Strongly Disagree        0.2048           Disagree        0.2048
#
#               Response 3  % Response 3                   Response 4  \
# 0  Somewhat Dissatisfied        0.1379                      Neutral
# 1  Somewhat Dissatisfied        0.1027                      Neutral
# 2      Somewhat Unlikely        0.0171  Neither Likely nor Unlikely
# 3      Somewhat Unlikely        0.0764  Neither Likely nor Unlikely
# 4      Slightly Disagree        0.1567   Neither Agree nor Disagree
#
#    % Response 4          Response 5  % Response 5      Response 6  \
# 0        0.0820  Somewhat Satisfied        0.2062  Very Satisfied
# 1        0.1025  Somewhat Satisfied        0.1444  Very Satisfied
# 2        0.0373     Somewhat Likely        0.0666     Very Likely
# 3        0.1516     Somewhat Likely        0.1811     Very Likely
# 4        0.1157      Slightly Agree        0.2078           Agree
#
#    % Response 6           Response 7  % Response 7
# 0        0.2920  Extremely Satisfied        0.0452
# 1        0.3455  Extremely Satisfied        0.0878
# 2        0.2036     Extremely Likely        0.6540
# 3        0.1946     Extremely Likely        0.2432
# 4        0.1688       Strongly Agree        0.0245

# %%
#melt data together based on response text
df_text = final_csat_df[['Date','Question','Total Response','Response 1','Response 2','Response 3','Response 4','Response 5', 'Response 6','Response 7']]
df_text_long = df_text.melt(id_vars=['Date','Question','Total Response']).sort_values('Date')
df_text_long.head(20)
# Out:
#            Date                                           Question  \
# 0    2018-01-01               How would you rate the mbta overall?
# 138  2018-01-01                                Vehicle cleanliness
# 139  2018-01-01                                  Speed/travel time
# 140  2018-01-01                               Parking availability
# 141  2018-01-01                           Real-time communications
# 142  2018-01-01  How satisfied are you with the MBTA's communic...
# 261  2018-01-01                                  Wait time at stop
# 260  2018-01-01  The mbta has a fleet of trains and buses that ...
# 259  2018-01-01            The mbta is a good value for the money.
# 258  2018-01-01  The mbta uses technology to meet the needs and...
# 257  2018-01-01         The mbta is a cost-conscious organization.
# 256  2018-01-01  The mbta provides reliable public transportati...
# 255  2018-01-01  How likely are you to recommend the mbta to a ...
# 254  2018-01-01  How likely are you to continue using the mbta ...
# 253  2018-01-01          How would you rate your most recent trip?
# 252  2018-01-01               How would you rate the mbta overall?
# 630  2018-01-01               How would you rate the mbta overall?
# 631  2018-01-01          How would you rate your most recent trip?
# 632  2018-01-01  How likely are you to continue using the mbta ...
# 633  2018-01-01  How likely are you to recommend the mbta to a ...
#
#      Total Response    variable                   value
# 0               895  Response 1  Extremely Dissatisfied
# 138             879  Response 2               Very Poor
# 139             885  Response 2               Very Poor
# 140             278  Response 2               Very Poor
# 141             833  Response 2               Very Poor
# 142             895  Response 2       Very Dissatisfied
# 261             884  Response 3                    Poor
# 260             882  Response 3       Slightly Disagree
# 259             883  Response 3       Slightly Disagree
# 258             883  Response 3       Slightly Disagree
# 257             880  Response 3       Slightly Disagree
# 256             883  Response 3       Slightly Disagree
# 255             883  Response 3       Somewhat Unlikely
# 254             884  Response 3       Somewhat Unlikely
# 253             886  Response 3   Somewhat Dissatisfied
# 252             895  Response 3   Somewhat Dissatisfied
# 630             895  Response 6          Very Satisfied
# 631             886  Response 6          Very Satisfied
# 632             884  Response 6             Very Likely
# 633             883  Response 6             Very Likely

# %%
#melt data together based on response %
df_percentage = final_csat_df[['Date','Question','Total Response','% Response 1','% Response 2','% Response 3','% Response 4','% Response 5', '% Response 6','% Response 7']]
#match columns from both dfs
df_percentage.columns = df_text.columns
df_percentage_long = df_percentage.melt(id_vars=['Date','Question','Total Response']).sort_values('Date')
df_percentage_long.head(20)
# Out:
#            Date                                           Question  \
# 0    2018-01-01               How would you rate the mbta overall?
# 138  2018-01-01                                Vehicle cleanliness
# 139  2018-01-01                                  Speed/travel time
# 140  2018-01-01                               Parking availability
# 141  2018-01-01                           Real-time communications
# 142  2018-01-01  How satisfied are you with the MBTA's communic...
# 261  2018-01-01                                  Wait time at stop
# 260  2018-01-01  The mbta has a fleet of trains and buses that ...
# 259  2018-01-01            The mbta is a good value for the money.
# 258  2018-01-01  The mbta uses technology to meet the needs and...
# 257  2018-01-01         The mbta is a cost-conscious organization.
# 256  2018-01-01  The mbta provides reliable public transportati...
# 255  2018-01-01  How likely are you to recommend the mbta to a ...
# 254  2018-01-01  How likely are you to continue using the mbta ...
# 253  2018-01-01          How would you rate your most recent trip?
# 252  2018-01-01               How would you rate the mbta overall?
# 630  2018-01-01               How would you rate the mbta overall?
# 631  2018-01-01          How would you rate your most recent trip?
# 632  2018-01-01  How likely are you to continue using the mbta ...
# 633  2018-01-01  How likely are you to recommend the mbta to a ...
#
#      Total Response    variable   value
# 0               895  Response 1  0.0922
# 138             879  Response 2  0.0456
# 139             885  Response 2  0.1114
# 140             278  Response 2  0.1255
# 141             833  Response 2  0.1352
# 142             895  Response 2  0.0914
# 261             884  Response 3  0.1141
# 260             882  Response 3  0.1473
# 259             883  Response 3  0.1057
# 258             883  Response 3  0.1244
# 257             880  Response 3  0.1343
# 256             883  Response 3  0.1567
# 255             883  Response 3  0.0764
# 254             884  Response 3  0.0171
# 253             886  Response 3  0.1027
# 252             895  Response 3  0.1379
# 630             895  Response 6  0.2920
# 631             886  Response 6  0.3455
# 632             884  Response 6  0.2036
# 633             883  Response 6  0.1946

# %%
#merge melted dfs
merged_df = pd.merge(df_text_long, df_percentage_long, on = ('Date','Question','Total Response','variable'))
#sort by survey id and variable
merged_df = merged_df.sort_values(['Date', 'variable'])
merged_df = merged_df.rename(columns={
                                      "value_x": "Response Value",
                                     "value_y": "Response %"})
merged_df.head(20)
# Out:
#           Date                                           Question  \
# 0   2018-01-01               How would you rate the mbta overall?
# 74  2018-01-01  How satisfied are you with the MBTA's communic...
# 75  2018-01-01                           Real-time communications
# 76  2018-01-01                               Parking availability
# 77  2018-01-01                                  Speed/travel time
# 79  2018-01-01                                Vehicle cleanliness
# 80  2018-01-01                   Stop condition &amp; cleanliness
# 81  2018-01-01                                  Wait time at stop
# 82  2018-01-01  The mbta has a fleet of trains and buses that ...
# 83  2018-01-01            The mbta is a good value for the money.
# 84  2018-01-01  The mbta uses technology to meet the needs and...
# 85  2018-01-01         The mbta is a cost-conscious organization.
# 86  2018-01-01  The mbta provides reliable public transportati...
# 87  2018-01-01  How likely are you to recommend the mbta to a ...
# 88  2018-01-01  How likely are you to continue using the mbta ...
# 89  2018-01-01          How would you rate your most recent trip?
# 90  2018-01-01                                Vehicle crowdedness
# 1   2018-01-01                                Vehicle cleanliness
# 2   2018-01-01                                  Speed/travel time
# 3   2018-01-01                               Parking availability
#
#     Total Response    variable          Response Value  Response %
# 0              895  Response 1  Extremely Dissatisfied      0.0922
# 74             895  Response 1  Extremely Dissatisfied      0.0914
# 75             833  Response 1            Unacceptable      0.1352
# 76             278  Response 1            Unacceptable      0.1255
# 77             885  Response 1            Unacceptable      0.1114
# 79             879  Response 1            Unacceptable      0.0456
# 80             869  Response 1            Unacceptable      0.0549
# 81             884  Response 1            Unacceptable      0.1226
# 82             882  Response 1       Strongly Disagree      0.1873
# 83             883  Response 1       Strongly Disagree      0.1138
# 84             883  Response 1       Strongly Disagree      0.1082
# 85             880  Response 1       Strongly Disagree      0.1712
# 86             883  Response 1       Strongly Disagree      0.2048
# 87             883  Response 1      Extremely Unlikely      0.0944
# 88             884  Response 1      Extremely Unlikely      0.0111
# 89             886  Response 1  Extremely Dissatisfied      0.1247
# 90             883  Response 1            Unacceptable      0.1177
# 1              879  Response 2               Very Poor      0.0456
# 2              885  Response 2               Very Poor      0.1114
# 3              278  Response 2               Very Poor      0.1255

# %%
#only "How would you rate the mbta overall?"
# only_overall_rate_df = merged_df.loc[merged_df["Question"] == "How would you rate the mbta overall?", :].reset_index(drop = True)
only_overall_rate_df = merged_df
#number of responses per value
only_overall_rate_df["Number of Responses"] = only_overall_rate_df["Total Response"]*only_overall_rate_df["Response %"]
#get rating column
only_overall_rate_df["Response Rating"] = only_overall_rate_df["variable"].str.replace("Response ", "").astype(int)
# only_overall_rate_df["Average Rating"] = np.average(only_overall_rate_df["Response Rating"], weights=only_overall_rate_df["Number of Responses"])
only_overall_rate_df["Weighted Rating"] = only_overall_rate_df["Response Rating"]*only_overall_rate_df["Number of Responses"]

only_overall_rate_df.head(20)
# Out:
#           Date                                           Question  \
# 0   2018-01-01               How would you rate the mbta overall?
# 74  2018-01-01  How satisfied are you with the MBTA's communic...
# 75  2018-01-01                           Real-time communications
# 76  2018-01-01                               Parking availability
# 77  2018-01-01                                  Speed/travel time
# 79  2018-01-01                                Vehicle cleanliness
# 80  2018-01-01                   Stop condition &amp; cleanliness
# 81  2018-01-01                                  Wait time at stop
# 82  2018-01-01  The mbta has a fleet of trains and buses that ...
# 83  2018-01-01            The mbta is a good value for the money.
# 84  2018-01-01  The mbta uses technology to meet the needs and...
# 85  2018-01-01         The mbta is a cost-conscious organization.
# 86  2018-01-01  The mbta provides reliable public transportati...
# 87  2018-01-01  How likely are you to recommend the mbta to a ...
# 88  2018-01-01  How likely are you to continue using the mbta ...
# 89  2018-01-01          How would you rate your most recent trip?
# 90  2018-01-01                                Vehicle crowdedness
# 1   2018-01-01                                Vehicle cleanliness
# 2   2018-01-01                                  Speed/travel time
# 3   2018-01-01                               Parking availability
#
#     Total Response    variable          Response Value  Response %  \
# 0              895  Response 1  Extremely Dissatisfied      0.0922
# 74             895  Response 1  Extremely Dissatisfied      0.0914
# 75             833  Response 1            Unacceptable      0.1352
# 76             278  Response 1            Unacceptable      0.1255
# 77             885  Response 1            Unacceptable      0.1114
# 79             879  Response 1            Unacceptable      0.0456
# 80             869  Response 1            Unacceptable      0.0549
# 81             884  Response 1            Unacceptable      0.1226
# 82             882  Response 1       Strongly Disagree      0.1873
# 83             883  Response 1       Strongly Disagree      0.1138
# 84             883  Response 1       Strongly Disagree      0.1082
# 85             880  Response 1       Strongly Disagree      0.1712
# 86             883  Response 1       Strongly Disagree      0.2048
# 87             883  Response 1      Extremely Unlikely      0.0944
# 88             884  Response 1      Extremely Unlikely      0.0111
# 89             886  Response 1  Extremely Dissatisfied      0.1247
# 90             883  Response 1            Unacceptable      0.1177
# 1              879  Response 2               Very Poor      0.0456
# 2              885  Response 2               Very Poor      0.1114
# 3              278  Response 2               Very Poor      0.1255
#
#     Number of Responses  Response Rating  Weighted Rating
# 0               82.5190                1          82.5190
# 74              81.8030                1          81.8030
# 75             112.6216                1         112.6216
# 76              34.8890                1          34.8890
# 77              98.5890                1          98.5890
# 79              40.0824                1          40.0824
# 80              47.7081                1          47.7081
# 81             108.3784                1         108.3784
# 82             165.1986                1         165.1986
# 83             100.4854                1         100.4854
# 84              95.5406                1          95.5406
# 85             150.6560                1         150.6560
# 86             180.8384                1         180.8384
# 87              83.3552                1          83.3552
# 88               9.8124                1           9.8124
# 89             110.4842                1         110.4842
# 90             103.9291                1         103.9291
# 1               40.0824                2          80.1648
# 2               98.5890                2         197.1780
# 3               34.8890                2          69.7780

# %%
sum_df = only_overall_rate_df[["Date", "Question", "Total Response", "Weighted Rating"]].groupby(["Date", "Question", "Total Response"])
responses_sum = sum_df.sum().reset_index()
responses_sum["Weighted Average"] = responses_sum["Weighted Rating"]/responses_sum["Total Response"]

responses_sum.head(20)
# Out:
#           Date                                           Question  \
# 0   2018-01-01  How likely are you to continue using the mbta ...
# 1   2018-01-01  How likely are you to recommend the mbta to a ...
# 2   2018-01-01  How satisfied are you with the MBTA's communic...
# 3   2018-01-01               How would you rate the mbta overall?
# 4   2018-01-01          How would you rate your most recent trip?
# 5   2018-01-01                               Parking availability
# 6   2018-01-01                           Real-time communications
# 7   2018-01-01                                  Speed/travel time
# 8   2018-01-01                   Stop condition &amp; cleanliness
# 9   2018-01-01  The mbta has a fleet of trains and buses that ...
# 10  2018-01-01         The mbta is a cost-conscious organization.
# 11  2018-01-01            The mbta is a good value for the money.
# 12  2018-01-01  The mbta provides reliable public transportati...
# 13  2018-01-01  The mbta uses technology to meet the needs and...
# 14  2018-01-01                                Vehicle cleanliness
# 15  2018-01-01                                Vehicle crowdedness
# 16  2018-01-01                                  Wait time at stop
# 17  2018-02-01  How likely are you to continue using the mbta ...
# 18  2018-02-01  How likely are you to recommend the mbta to a ...
# 19  2018-02-01  How satisfied are you with the MBTA's communic...
#
#     Total Response  Weighted Rating  Weighted Average
# 0              884      5627.897600            6.3664
# 1              883      4321.666900            4.8943
# 2              895      3706.284500            4.1411
# 3              895      3685.341500            4.1177
# 4              886      3988.594800            4.5018
# 5              278      1261.286000            4.5370
# 6              833      3638.294100            4.3677
# 7              885      4092.594000            4.6244
# 8              869      3992.968100            4.5949
# 9              882      3087.352800            3.5004
# 10             880      3327.456000            3.7812
# 11             883      3835.487100            4.3437
# 12             883      3329.439800            3.7706
# 13             883      3513.368700            3.9789
# 14             879      4166.723700            4.7403
# 15             883      4101.623300            4.6451
# 16             884      4128.633600            4.6704
# 17             785      5065.840500            6.4533
# 18             785      4019.356999            5.1202
# 19             798      3424.776600            4.2917

# %%
overallMBTA_rate_df = responses_sum.loc[responses_sum["Question"] == "How would you rate the mbta overall?", :]
overallMBTA_rate_df
# Out:
#            Date                              Question  Total Response  \
# 3    2018-01-01  How would you rate the mbta overall?             895
# 20   2018-02-01  How would you rate the mbta overall?             798
# 37   2018-03-01  How would you rate the mbta overall?             720
# 54   2018-04-01  How would you rate the mbta overall?             688
# 71   2018-05-01  How would you rate the mbta overall?             768
# 88   2018-06-01  How would you rate the mbta overall?             779
# 103  2018-07-01  How would you rate the mbta overall?            1878
# 107  2018-08-01  How would you rate the mbta overall?            1874
# 111  2018-09-01  How would you rate the mbta overall?            1691
# 115  2018-10-01  How would you rate the mbta overall?            1489
# 119  2018-11-01  How would you rate the mbta overall?            1391
# 123  2018-12-01  How would you rate the mbta overall?            1300
#
#      Weighted Rating  Weighted Average
# 3          3685.3415            4.1177
# 20         3556.7658            4.4571
# 37         3228.9840            4.4847
# 54         3155.0992            4.5859
# 71         3410.1504            4.4403
# 88         3443.4916            4.4204
# 103        8327.0520            4.4340
# 107        8164.8306            4.3569
# 111        7309.5166            4.3226
# 115        6698.1176            4.4984
# 119        6135.7010            4.4110
# 123        5787.3400            4.4518

# %%
speed_travel_df = responses_sum.loc[responses_sum["Question"] == "Speed/travel time", :]
#speed_travel_df
reliable_tran_df = responses_sum.loc[responses_sum["Question"] == "The mbta provides reliable public transportation services.", :]
#reliable_tran_df
parking_df = responses_sum.loc[responses_sum["Question"] == "Parking availability", :]
#parking_df
clean_well_df = responses_sum.loc[responses_sum["Question"] == "The mbta has a fleet of trains and buses that are clean and well maintained.", :]
clean_well_df
# Out:
#           Date                                           Question  \
# 9   2018-01-01  The mbta has a fleet of trains and buses that ...
# 26  2018-02-01  The mbta has a fleet of trains and buses that ...
# 43  2018-03-01  The mbta has a fleet of trains and buses that ...
# 60  2018-04-01  The mbta has a fleet of trains and buses that ...
# 77  2018-05-01  The mbta has a fleet of trains and buses that ...
# 94  2018-06-01  The mbta has a fleet of trains and buses that ...
#
#     Total Response  Weighted Rating  Weighted Average
# 9              882        3087.3528            3.5004
# 26             783        2847.0663            3.6361
# 43             711        2587.7556            3.6396
# 60             682        2564.3882            3.7601
# 77             752        2806.5392            3.7321
# 94             723        2675.6784            3.7008

# %%
x_axis = np.arange(1, 13, 1.0)
plt.plot(x_axis, overallMBTA_rate_df["Weighted Average"], color='green', label='Overall Rating')
plt.plot(x_axis, reliable_tran_df["Weighted Average"],color='orange', label='Reliable')
# plt.plot(x_axis, parking_df["Weighted Average"], color='green', label='Parking Availability')
plt.xticks(np.arange(1, 12+1, 1.0))
plt.legend(loc="best")
#plt.xticks(rotation = "vertical")
plt.ylim(0, 7)
# Out:
# (0, 7)

# %%
plt.plot(parking_df["Date"], parking_df["Weighted Average"], color='green', label='Parking Availability')
plt.xticks(np.arange(1, 12+1, 1.0), rotation='vertical')
plt.ylim(0, 7)
# Out:
# (0, 7)
